# %% [markdown]
# link para o colab

# %% [markdown]
# # Aquisição de Dados
# O texto escolhido foi  discurso do Bolsonaro durante a conferencia da ONU em 2019-09-24 porque se trata do atual representante do nosso país em uma conferência de grande importância geopolítica.

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/PARADIGMAS DE LINGUAGEM DE PROGRAMAÇÃO EM CIÊNCIA DE DADOS/T1/Discurso_Bolsonaro_ONU_20190924.txt'
with open(file_path,'r') as f:
  text = f.read()
texto = text.split()

# %% [markdown]
# # Descarte de caracteres especiais

# %%
for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','')

# %% [markdown]
# # Construção do Dicionário

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'"senhor': 1, 'presidente': 4, 'da': 37, 'assembleia': 1, 'geral': 1, 'tijjani': 1, 'muhammad-bande': 1, 'senhor': 1, 'secretário-geral': 1, 'onu': 4, 'antónio': 1, 'guterres': 1, 'chefes': 2, 'de': 124, 'estado': 2, 'governo': 9, 'e': 139, 'delegação': 1, 'senhoras': 4, 'senhores': 6, 'apresento': 2, 'aos': 8, 'um': 31, 'novo': 2, 'brasil': 32, 'que': 67, 'ressurge': 1, 'depois': 1, 'estar': 2, 'à': 12, 'beira': 1, 'do': 41, 'socialismo': 5, 'está': 9, 'sendo': 2, 'reconstruído': 1, 'a': 91, 'partir': 1, 'dos': 12, 'anseios': 1, 'ideais': 1, 'seu': 4, 'povo': 3, 'no': 18, 'meu': 9, 'o': 66, 'vem': 1, 'trabalhando': 1, 'para': 42, 'reconquistar': 1, 'confiança': 2, 'mundo': 11, 'diminuindo': 1, 'desemprego': 1, 'violência': 4, 'risco': 1, 'os': 26, 'negócios': 1, 'por': 19, 'meio': 3, 'desburocratização': 1, 'desregulamentação': 1, 'em': 47, 'especial': 5, 'pelo': 6, 'exemplo': 2, 'país': 12, 'esteve': 1, 'muito': 3, 'próximo': 1, 'nos': 15, 'colocou': 1, 'numa': 1, 'situação': 1, '
# ...

# %% [markdown]
# # Eibição dos Resultados

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()

# %% [markdown]
# # Conclusão
#   Como esperado, preposições e artigos foram as palavras mais utilizadas. O substantivo mais utilizado foi '*brasil*', seguido de '*países*', '*país*', '*outros*', '*todos*','*mundo*', '*governo*', '*liberdade*', '*direitos*', '*organização*', '*amazônia*', '*humanos*'.Além disso, a maioria dos verbos e pronomes são da '*segunda pessoa do plural*'.
# Como conclusão é possível perceber que o discurso teve paltas internacionais, focando no Brasil. De maneira coletiva (evidenciada pela conjugação do verbo).
#     Tendo em vista que ele representa o Brasil e tem grande apelo popular, considero o discurso coerente com suas posturas anteriores.
